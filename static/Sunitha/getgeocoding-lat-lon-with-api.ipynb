# %% [markdown]
# ##  You’ll need to either manually get the (lat, long) or find an API that will return a (lat, long) of a city given the city name (we used the Google Maps API to do this)

# %% [markdown]
# ### I tried with Carto, but unfortunately it does not give the lat, long for free.

# %% [markdown]
# https://pypi.python.org/pypi/geopy#downloads

# %%
# !pip install geopy

# %%
import pandas as pd
import numpy as np
import json

# %%
df = pd.read_csv('./Data/MassShootings_2013-2018.csv')
df.head()
# Out:
#      date  name_semicolon_delimited  killed  wounded        city state  \
# 0  1/1/13                   Unknown       1        3   Hawthorne    CA
# 1  1/1/13  Desmen Noble;Damian Bell       1        4      Lorain    OH
# 2  1/1/13               Julian Sims       0        4  McKeesport    PA
# 3  1/1/13           Carlito Montoya       2        3  Sacramento    CA
# 4  1/5/13           Sonny Archuleta       4        0      Aurora    CO
#
#                          sources_semicolon_delimited
# 0  http://losangeles.cbslocal.com/2013/01/01/man-...
# 1  http://www.wkyc.com/news/article/276177/3/Lora...
# 2  http://pittsburgh.cbslocal.com/2013/01/01/4-pe...
# 3  http://sacramento.cbslocal.com/2013/01/01/4-sh...
# 4  http://www.dailydemocrat.com/ci_22322664/auror...

# %%
df['city']  # as a Series
# Out:
# 0           Hawthorne
# 1              Lorain
# 2          McKeesport
# 3          Sacramento
# 4              Aurora
# 5               Tulsa
# 6          Greensboro
# 7           Dinwiddie
# 8         New Orleans
# 9         Albuquerque
# 10        New Orleans
# 11          Brentwood
# 12          St. Louis
# 13        Springfield
# 14         Washington
# 15          Charenton
# 16            Phoenix
# 17            Oakland
# 18            Memphis
# 19            Memphis
# 20         Olivehurst
# 21             Denver
# 22            Chicago
# 23        New Orleans
# 24            Vallejo
# 25         Wilmington
# 26            Midvale
# 27      Winston-Salem
# 28             Tustin
# 29              Miami
#             ...
# 1978     Indianapolis
# 1979          Reading
# 1980      Los Angeles
# 1981    Bowling Green
# 1982            Ocala
# 1983       Byromville
# 1984       Washington
# 1985           Benton
# 1986     Philadelphia
# 1987          Chicago
# ...

# %%
cities = df['city'].values  # as a numpy array
cities
# Out:
# array(['Hawthorne', 'Lorain', 'McKeesport', ..., 'Brinkley', 'Columbus',
#        'Huntsville'], dtype=object)

# %% [markdown]
# # Geocoding
# To geolocate a query to an address and coordinates:

# %%
from geopy.geocoders import Nominatim
geolocator = Nominatim()

cities = df['city'].values  # as a numpy array 

for city in cities:
    location = geolocator.geocode(city)
    print(location.address)
    print((location.latitude, location.longitude))

    #print(location.raw)
# Out:
# Hawthorne, Los Angeles County, California, United States of America
# (33.911454, -118.34816)
# Lorain, Lorain County, Ohio, United States of America
# (41.4673238, -82.1781904)
# McKeesport, Allegheny County, Pennsylvania, United States of America
# (40.3478472, -79.864215)
# Sacramento, Sacramento County, California, United States of America
# (38.5815719, -121.4943996)
# Aurora, Kane County, Illinois, United States of America
# (41.7571701, -88.3147539)
# Tulsa, Tulsa County, Oklahoma, United States of America
# (36.1556805, -95.9929113)
# Greensboro, Guilford County, North Carolina, United States of America
# (36.0726355, -79.7919754)
# Dinwiddie County, Virginia, United States of America
# (37.0712818, -77.6480714)
# New Orleans, Orleans Parish, Louisiana, United States of America
# (30.03280175, -89.9750054503052)
# Albuquerque, Corumbá, Microrregião do Baixo Pantanal, Mesorregião Pantanal Sul Matro-Grossense, MS, Região Centro-Oeste, 79300-000, Brasil
# ...

# %%
#https://maps.googleapis.com/maps/api/geocode/json?address=Hawthorne&key=AIzaSyCLE_2Yfxa_y12nZv53kflN0oYnxYDcQVI
#https://developers.google.com/maps/documentation/geocoding/intro
